# %% [markdown]
# <a href="https://colab.research.google.com/github/D3MOboyyy/D3MOboyyy/blob/main/parkinsons.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()  # prompts you to select the CSV file from your computer
import io
import pandas as pd
df = pd.read_csv(io.BytesIO(uploaded['parkinsons.csv']))
# Out:
#      <input type="file" id="files-526d4346-6585-4315-9425-2df143efcfa9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-526d4346-6585-4315-9425-2df143efcfa9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
print("Shape:", df.shape)
print("Columns and types:")
print(df.dtypes)
print("\nTarget distribution:\n", df['status'].value_counts())

df.describe().transpose()
# Out:
# Shape: (195, 24)
# Columns and types:
# name                 object
# MDVP:Fo(Hz)         float64
# MDVP:Fhi(Hz)        float64
# MDVP:Flo(Hz)        float64
# MDVP:Jitter(%)      float64
# MDVP:Jitter(Abs)    float64
# MDVP:RAP            float64
# MDVP:PPQ            float64
# Jitter:DDP          float64
# MDVP:Shimmer        float64
# MDVP:Shimmer(dB)    float64
# Shimmer:APQ3        float64
# Shimmer:APQ5        float64
# MDVP:APQ            float64
# Shimmer:DDA         float64
# NHR                 float64
# HNR                 float64
# status                int64
# RPDE                float64
# DFA                 float64
# spread1             float64
# spread2             float64
# D2                  float64
# PPE                 float64
# dtype: object
#
# Target distribution:
#  status
# 1    147
# 0     48
# Name: count, dtype: int64
#                   count        mean        std         min         25%  \
# ...

# %%
print(df.isnull().sum())
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
import numpy as np
outlier_counts = {}
for col in df.select_dtypes(include=[np.number]).columns.drop(['status']):
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    low = Q1 - 1.5*IQR
    high = Q3 + 1.5*IQR
    count = ((df[col] < low) | (df[col] > high)).sum()
    outlier_counts[col] = count

print("Outliers per feature (IQR method):")
print(outlier_counts)
# Out:
# Outliers per feature (IQR method):
# {'MDVP:Fo(Hz)': np.int64(0), 'MDVP:Fhi(Hz)': np.int64(11), 'MDVP:Flo(Hz)': np.int64(9), 'MDVP:Jitter(%)': np.int64(14), 'MDVP:Jitter(Abs)': np.int64(7), 'MDVP:RAP': np.int64(14), 'MDVP:PPQ': np.int64(15), 'Jitter:DDP': np.int64(14), 'MDVP:Shimmer': np.int64(8), 'MDVP:Shimmer(dB)': np.int64(10), 'Shimmer:APQ3': np.int64(6), 'Shimmer:APQ5': np.int64(13), 'MDVP:APQ': np.int64(12), 'Shimmer:DDA': np.int64(6), 'NHR': np.int64(19), 'HNR': np.int64(3), 'RPDE': np.int64(0), 'DFA': np.int64(0), 'spread1': np.int64(4), 'spread2': np.int64(2), 'D2': np.int64(1), 'PPE': np.int64(5)}

# %%
# !pip install imbalanced-learn        # run this in Colab
from imblearn.over_sampling import SMOTE
from imblearn.combine import SMOTEENN

# Split data before oversampling:
from sklearn.model_selection import train_test_split
X = df.drop(columns=['name','status'])
y = df['status']
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42)
print("Train class counts:", np.bincount(y_train))
print("Test class counts:", np.bincount(y_test))
# Out:
# ...
# Train class counts: [ 38 118]
# Test class counts: [10 29]

# %%
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)
print("After SMOTE train counts:", np.bincount(y_train_smote))
# Out:
# After SMOTE train counts: [118 118]

# %%
from sklearn.feature_selection import SelectKBest, f_classif
selector = SelectKBest(score_func=f_classif, k=10)
selector.fit(X_train, y_train)
print("SelectKBest selected features:", X.columns[selector.get_support()])
# Out:
# SelectKBest selected features: Index(['MDVP:Flo(Hz)', 'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ5',
#        'MDVP:APQ', 'HNR', 'spread1', 'spread2', 'D2', 'PPE'],
#       dtype='object')

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
rfe = RFE(LogisticRegression(max_iter=1000), n_features_to_select=10)
rfe.fit(X_train, y_train)
print("RFE selected features:", X.columns[rfe.support_])
# Out:
# RFE selected features: Index(['MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'MDVP:APQ', 'Shimmer:DDA', 'RPDE',
#        'DFA', 'spread1', 'spread2', 'D2', 'PPE'],
#       dtype='object')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

models = {
  'Logistic Regression': LogisticRegression(max_iter=1000),
  'Random Forest': RandomForestClassifier(random_state=42),
  'XGBoost': xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)
}
results = {}
for name, model in models.items():
    model.fit(X_train, y_train)
    preds = model.predict(X_test)
    probs = model.predict_proba(X_test)[:,1]
    results[name] = {
        'Accuracy': accuracy_score(y_test, preds),
        'Precision': precision_score(y_test, preds),
        'Recall': recall_score(y_test, preds),
        'F1-score': f1_score(y_test, preds),
        'ROC-AUC': roc_auc_score(y_test, probs)
    }
print(results)
# Out:
# {'Logistic Regression': {'Accuracy': 0.9230769230769231, 'Precision': 0.9333333333333333, 'Recall': 0.9655172413793104, 'F1-score': 0.9491525423728814, 'ROC-AUC': np.float64(0.8896551724137931)}, 'Random Forest': {'Accuracy': 0.9230769230769231, 'Precision': 0.9333333333333333, 'Recall': 0.9655172413793104, 'F1-score': 0.9491525423728814, 'ROC-AUC': np.float64(0.9620689655172414)}, 'XGBoost': {'Accuracy': 0.9230769230769231, 'Precision': 0.9333333333333333, 'Recall': 0.9655172413793104, 'F1-score': 0.9491525423728814, 'ROC-AUC': np.float64(0.9758620689655173)}}
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:183: UserWarning: [20:27:25] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'max_depth': [3,5,7],
    'n_estimators': [50, 100, 150],
    'learning_rate': [0.01, 0.1, 0.3]
}
grid = GridSearchCV(xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42),
                    param_grid, scoring='roc_auc', cv=3)
grid.fit(X_train, y_train)
print("Best params:", grid.best_params_)
print("Best ROC-AUC (CV):", grid.best_score_)
# Out:
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:183: UserWarning: [20:27:31] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:183: UserWarning: [20:27:31] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:183: UserWarning: [20:27:31] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:183: UserWarning: [20:27:31] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ...

# %%
from sklearn.ensemble import VotingClassifier, StackingClassifier
ensemble = VotingClassifier(
    estimators=[('lr', models['Logistic Regression']), ('rf', models['Random Forest']), ('xgb', models['XGBoost'])],
    voting='soft'
)
ensemble.fit(X_train, y_train)
ensemble_preds = ensemble.predict(X_test)
print("Ensemble ROC-AUC:", roc_auc_score(y_test, ensemble.predict_proba(X_test)[:,1]))
# Out:
# Ensemble ROC-AUC: 0.9551724137931035
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:183: UserWarning: [19:42:26] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)

# %%
import shap
import xgboost as xgb

# Fit an XGBoost model (or use your best-performing model)
model = xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)
model.fit(X_train, y_train)

# Explain predictions with SHAP
explainer = shap.TreeExplainer(model)
shap_values = explainer(X_test)

# Visualize feature importance
shap.summary_plot(shap_values.values, X_test, feature_names=X.columns)
# Out:
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:183: UserWarning: [20:30:14] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)

# %%
# !pip install lime
from lime.lime_tabular import LimeTabularExplainer
explainer = LimeTabularExplainer(
    training_data=X_train.values,
    feature_names=X.columns,
    class_names=['Healthy','Parkinson'],
    mode='classification'
)
exp = explainer.explain_instance(
    data_row=X_test.iloc[0].values,
    predict_fn=model.predict_proba,
    num_features=5
)
print(exp.as_list())
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 5.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for lime: filename=lime-0.2.0.1-py3-none-any.whl size=283834 sha256=65d6f553c1ae1fc38aff668c1ac5dbfe48d294a4dfdac698f65808b6f0599bf0
#   Stored in directory: /root/.cache/pip/wheels/e7/5d/0e/4b4fff9a47468fed5633211fb3b76d1db43fe806a17fb7486a
# Successfully built lime
# ...
# [('spread2 <= 0.18', -0.1330843550623287), ('D2 <= 2.10', -0.12526577276257603), ('MDVP:Fo(Hz) <= 117.79', -0.10596047898083737), ('0.21 < PPE <= 0.26', 0.08280251020322447), ('MDVP:RAP <= 0.00', -0.07826114426582192)]
